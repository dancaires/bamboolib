# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("df_now_clear.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Comando para não limitar visualização de colunas.

# %%
df.head()
# Out:
#       id  host_since host_response_time  host_response_rate  \
# 0  17878  2010-01-08     within an hour               100.0
# 1  25026  2010-04-03       within a day                91.0
# 2  31560  2010-05-31     within an hour               100.0
# 3  35636  2010-06-27     within an hour               100.0
# 4  35764  2010-06-27     within an hour               100.0
#
#    host_is_superhost                                 host_verifications  \
# 0               True  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 1              False  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 2               True  ['email', 'phone', 'manual_online', 'facebook'...
# 3               True  ['email', 'phone', 'facebook', 'reviews', 'man...
# 4               True  ['email', 'phone', 'reviews', 'jumio', 'govern...
#
#    host_identity_verified neighbourhood  latitude  longitude property_type  \
# 0                    True    Copacabana -22.96592  -43.17896   Condominium
# ...

# %% [markdown]
# head() Mostra as 5 primeiras linhas do dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33708 entries, 0 to 33707
# Data columns (total 34 columns):
# id                             33708 non-null int64
# host_since                     33688 non-null object
# host_response_time             21474 non-null object
# host_response_rate             21474 non-null float64
# host_is_superhost              33708 non-null bool
# host_verifications             33708 non-null object
# host_identity_verified         33708 non-null bool
# neighbourhood                  31750 non-null object
# latitude                       33708 non-null float64
# longitude                      33708 non-null float64
# property_type                  33708 non-null object
# room_type                      33708 non-null object
# accommodates                   33708 non-null int64
# bathrooms                      33654 non-null float64
# bedrooms                       33666 non-null float64
# beds                           33660 non-null float64
# ...

# %% [markdown]
# info() Mostra um panorama geral do dataset.

# %%
df["room_type"].value_counts()
# Out:
# Entire home/apt    23946
# Private room        8734
# Shared room          715
# Hotel room           313
# Name: room_type, dtype: int64

# %% [markdown]
# value_counts() Quantifica as features de atributo categorico.

# %%
df.describe()
# Out:
#                  id  host_response_rate      latitude     longitude  \
# count  3.370800e+04        21474.000000  33708.000000  33708.000000
# mean   1.837682e+07           85.412406    -22.965207    -43.254235
# std    1.182953e+07           26.400520      0.035248      0.097491
# min    1.787800e+04            0.000000    -23.073400    -43.737090
# 25%    1.026645e+07           83.000000    -22.984710    -43.323368
# 50%    1.425235e+07          100.000000    -22.970855    -43.200220
# 75%    2.991495e+07          100.000000    -22.946710    -43.187078
# max    4.029091e+07          100.000000    -22.750380    -43.104060
#
#        accommodates     bathrooms      bedrooms          beds         price  \
# count  33708.000000  33654.000000  33666.000000  33660.000000  33708.000000
# mean       4.200338      1.694910      1.646231      2.574421    651.995906
# std        2.625361      1.508351      1.075725      2.121622   1695.597110
# ...

# %% [markdown]
# describe() Apresenta um resumo dos atributos numéricos.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df["price"].hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# Plotagem do Histograma do atributo preço, nitidamente muita variância.
