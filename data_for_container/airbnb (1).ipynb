# %%
import bamboolib as bam
bam.enable()
# Out:
# Success: the bamboolib extension was enabled successfully. You can disable it via 'bam.disable()'. You will now see a magic bamboolib button when you display your dataframes, for example via 'df'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/Rio_listings_near_clear.csv")

# %%
df
# bamboolib code export - don't write below - rerun cell to execute code
df = df.drop(columns=['Unnamed: 0'])
df['host_is_superhost'] = df['host_is_superhost'].replace('t', 'TRUE')
df['host_is_superhost'] = df['host_is_superhost'].replace('F', 'FALSE')
df['host_is_superhost'] = df['host_is_superhost'].replace('f', 'FALSE')
# Out:
#        Unnamed: 0        id experiences_offered  host_since  \
# 0               0     17878                none  2010-01-08
# 1               1     25026                none  2010-04-03
# 2               2     31560                none  2010-05-31
# 3               3     35636                none  2010-06-27
# 4               4     35764                none  2010-06-27
# ...           ...       ...                 ...         ...
# 33710       33710  40289331                none  2017-03-15
# 33711       33711  40289841                none  2014-03-10
# 33712       33712  40290087                none  2017-06-09
# 33713       33713  40290464                none  2019-09-09
# 33714       33714  40290908                none  2016-03-23
#
#        host_response_time host_response_rate host_is_superhost  \
# 0          within an hour               100%                 t
# 1            within a day                91%                 f
# ...
